# %%
import pandas as pd

pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %% [markdown]
# # RQ3: Did the sustainability-aware explanation types within each domain differ in terms of (1) perceived sustainability-focused dimensions and in terms of (2) perceived explanation goals?

# %% [markdown]
# ## Sustainability-focused dimensions

# %%
import pandas as pd
from scipy.stats import shapiro, kruskal, mannwhitneyu
import itertools
from pathlib import Path

BASE_DIR = Path.home() / "Desktop" / "Sustainable-Aware-Exp" / "Hotels"
df = pd.read_csv(BASE_DIR / "merged_all_hotels_treatment.csv")

cat_cols = [
    'Group',
    'SustainabilityInclination/Influence',
    'SustainabilityAwareness/Effectiveness',
    'SustainabilityImportance',

]

likert_map = {
    'Strongly Disagree': 1,
    'Disagree'         : 2,
    'Neutral'          : 3,
    'Agree'            : 4,
    'Strongly Agree'   : 5
}

for col in cat_cols[1:]:
    print(f"\n=== {col} ===")
    ct = pd.crosstab(df[col], df['Group'])
    print("\nCounts:\n", ct)
    print("\n% within each level:\n", (ct.div(ct.sum(axis=1),axis=0)*100).round(1))

    positive = ct.loc[['Agree','Strongly Agree']].sum()
    print("\nSum of Agree + Strongly Agree by Group:\n", positive)


    code_col = f"{col}_code"
    df[code_col] = df[col].map(likert_map)
    sub = df.dropna(subset=[code_col, 'Group'])
    
    
    # ==== Shapiro–Wilk per group ====
    print("\nShapiro–Wilk normality test per Group:")
    normal_pvals = []
    for g in sub['Group'].unique():
        vals = sub.loc[sub['Group']==g, code_col]
        w_stat, p_norm = shapiro(vals)
        normal_pvals.append(p_norm)
        print(f"  {g:<20} W={w_stat:.3f}, p={p_norm:.3f}")
    if all(p > 0.05 for p in normal_pvals):
        print("  → All groups look roughly normal (p > .05)")
    else:
        print("  → At least one group is non‑normal (p ≤ .05), using Kruskal–Wallis")
   
    
    # ==== Kruskal–Wallis ====
    groups = sub['Group'].unique()

    samples = [sub.loc[sub['Group']==g, code_col] for g in groups]
    h_stat, p_val = kruskal(*samples)
    print(f"\nKruskal–Wallis H = {h_stat:.2f}, p = {p_val:.3f}")
    
    # pairwise follow‑ups mann whitey
    if p_val < 0.05:
        m = len(groups)*(len(groups)-1)/2
        alpha_bonf = 0.05 / m
        print(f" Pairwise Mann–Whitney U tests (α′={alpha_bonf:.4f}):")
        for g1, g2 in itertools.combinations(groups, 2):
            a = sub.loc[sub['Group']==g1, code_col]
            b = sub.loc[sub['Group']==g2, code_col]
            u, p_u = mannwhitneyu(a, b, alternative='two-sided')
            p_adj = min(p_u * m, 1.0)
            sig = "yes" if p_adj < 0.05 else "no"
            print(f"  {g1} vs {g2}: U={u}, raw p={p_u:.3f}, adj p={p_adj:.3f} → sig? {sig}")
    print("-"*60)
# Out:
# === SustainabilityInclination/Influence ===
#
# Counts:
#  Group                                ExternalInformation  Framing  Salience  Simplification
# SustainabilityInclination/Influence
# Agree                                                 15       12        11              16
# Disagree                                               0        3         7               6
# Neutral                                                5        4         3               3
# Strongly Agree                                        10       10         8               5
# Strongly Disagree                                      0        1         1               0
#
# % within each level:
#  Group                                ExternalInformation  Framing  Salience  Simplification
# SustainabilityInclination/Influence
# Agree                                               27.8     22.2      20.4            29.6
# Disagree                                             0.0     18.8      43.8            37.5
# Neutral                                             33.3     26.7      20.0            20.0
# Strongly Agree                                      30.3     30.3      24.2            15.2
# Strongly Disagree                                    0.0     50.0      50.0             0.0
#
# Sum of Agree + Strongly Agree by Group:
#  Group
# ExternalInformation    25
# Framing                22
# Salience               19
# Simplification         21
# dtype: int64
#
# Shapiro–Wilk normality test per Group:
#   Salience             W=0.858, p=0.001
#   Framing              W=0.840, p=0.000
#   Simplification       W=0.809, p=0.000
#   ExternalInformation  W=0.800, p=0.000
#   → At least one group is non‑normal (p ≤ .05), using Kruskal–Wallis
#
# Kruskal–Wallis H = 4.31, p = 0.230
# ------------------------------------------------------------
#
# === SustainabilityAwareness/Effectiveness ===
#
# Counts:
#  Group                                  ExternalInformation  Framing  Salience  Simplification
# SustainabilityAwareness/Effectiveness
# Agree                                                   16       14        15              14
# Disagree                                                 0        0         3               1
# Neutral                                                  4        7         5               6
# Strongly Agree                                          10        8         5               9
# Strongly Disagree                                        0        1         2               0
#
# % within each level:
#  Group                                  ExternalInformation  Framing  Salience  Simplification
# SustainabilityAwareness/Effectiveness
# Agree                                                 27.1     23.7      25.4            23.7
# Disagree                                               0.0      0.0      75.0            25.0
# Neutral                                               18.2     31.8      22.7            27.3
# Strongly Agree                                        31.2     25.0      15.6            28.1
# Strongly Disagree                                      0.0     33.3      66.7             0.0
#
# Sum of Agree + Strongly Agree by Group:
#  Group
# ExternalInformation    26
# Framing                22
# Salience               20
# Simplification         23
# dtype: int64
#
# Shapiro–Wilk normality test per Group:
#   Salience             W=0.846, p=0.001
#   Framing              W=0.826, p=0.000
#   Simplification       W=0.845, p=0.000
#   ExternalInformation  W=0.789, p=0.000
#   → At least one group is non‑normal (p ≤ .05), using Kruskal–Wallis
#
# Kruskal–Wallis H = 4.93, p = 0.177
# ------------------------------------------------------------
#
# === SustainabilityImportance ===
#
# Counts:
#  Group                     ExternalInformation  Framing  Salience  Simplification
# SustainabilityImportance
# Agree                                      12       14        10              14
# Disagree                                    1        0         4               2
# Neutral                                     8        7         6               3
# Strongly Agree                              9        8         8              11
# Strongly Disagree                           0        1         2               0
#
# % within each level:
#  Group                     ExternalInformation  Framing  Salience  Simplification
# SustainabilityImportance
# Agree                                    24.0     28.0      20.0            28.0
# Disagree                                 14.3      0.0      57.1            28.6
# Neutral                                  33.3     29.2      25.0            12.5
# Strongly Agree                           25.0     22.2      22.2            30.6
# Strongly Disagree                         0.0     33.3      66.7             0.0
#
# Sum of Agree + Strongly Agree by Group:
#  Group
# ExternalInformation    21
# Framing                22
# Salience               18
# Simplification         25
# dtype: int64
#
# Shapiro–Wilk normality test per Group:
#   Salience             W=0.883, p=0.003
#   Framing              W=0.826, p=0.000
#   Simplification       W=0.804, p=0.000
#   ExternalInformation  W=0.854, p=0.001
#   → At least one group is non‑normal (p ≤ .05), using Kruskal–Wallis
#
# Kruskal–Wallis H = 3.27, p = 0.352
# ------------------------------------------------------------

# %% [markdown]
# # Figure 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

BASE_DIR = Path.home() / "Desktop" / "Sustainable-Aware-Exp" / "Hotels"
df = pd.read_csv(BASE_DIR / "merged_all_hotels_treatment.csv")

questions = [
    'SustainabilityInclination/Influence',    #Persuasiveness
    'SustainabilityAwareness/Effectiveness',  #Effectiveness
    'SustainabilityImportance',               #Importance
]

likert_order = [
    'Strongly Disagree', 'Disagree', 'Neutral',
    'Agree', 'Strongly Agree'
]

colors = ["#d73027", "#fc8d59", "#fee08b", "#d9ef8b", "#1a9850"]
melted = df.melt(
    id_vars=['Group'], 
    value_vars=questions,
    var_name='Question', 
    value_name='Level'
)
melted['Level'] = pd.Categorical(
    melted['Level'],
    categories=likert_order,
    ordered=True
)


new_labels = [
    "External Infomration",
    "Positive Framing",
    "Increased Salience",
    "Simplification",
]


titles = {
    'SustainabilityInclination/Influence': "Persuasiveness",
    'SustainabilityAwareness/Effectiveness': "Effectiveness",
    'SustainabilityImportance': "Importance"
}

fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

for ax, q in zip(axes, questions):
    ct = (
        melted[melted['Question'] == q]
        .groupby(['Group', 'Level'])
        .size()
        .unstack(fill_value=0)
    )
    pct = ct.div(ct.sum(axis=1), axis=0) * 100
    
    pct.plot(
        kind='barh',
        stacked=True,
        color=colors,
        ax=ax,
        legend=False  
    )
    ax.set_title(titles[q], fontsize=14)
    ax.set_xlabel("Percent (%)")
    ax.set_xlim(0, 100)
    ax.set_yticklabels(new_labels)
    ax.set_ylabel(" ")


handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles, 
    labels, 
    title=" ", 
    bbox_to_anchor=(0.45, -0.01), 
    ncol=5, 
    loc='upper center',
    frameon=False
)

fig.suptitle("Tourism", fontsize=16, fontweight='bold')
plt.tight_layout(rect=[0, 0, 0.85, 0.95])
plt.show()
# Out:
# /var/folders/x5/4x0pvs_971l5vwmtfgh5snfr0000gn/T/ipykernel_6669/3798711867.py:60: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(['Group', 'Level'])
# /var/folders/x5/4x0pvs_971l5vwmtfgh5snfr0000gn/T/ipykernel_6669/3798711867.py:60: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(['Group', 'Level'])
# /var/folders/x5/4x0pvs_971l5vwmtfgh5snfr0000gn/T/ipykernel_6669/3798711867.py:60: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(['Group', 'Level'])

# %% [markdown]
# ## Explanation goals?

# %%
import pandas as pd
from scipy.stats import shapiro, kruskal, mannwhitneyu
import itertools
from pathlib import Path

BASE_DIR = Path.home() / "Desktop" / "Sustainable-Aware-Exp" / "Hotels"
df = pd.read_csv(BASE_DIR / "merged_all_hotels_treatment.csv")

cat_cols = [
    'Group',
    'Efectiveness',
    'Transparency', 
    'Persuadiveness', 
    'Scrutability', 
    'Efficiency',
    'Trust',
    'Satisfaction'

]

likert_map = {
    'Strongly Disagree': 1,
    'Disagree'         : 2,
    'Neutral'          : 3,
    'Agree'            : 4,
    'Strongly Agree'   : 5
}

for col in cat_cols[1:]:
    print(f"\n=== {col} ===")
    ct = pd.crosstab(df[col], df['Group'])
    print("\nCounts:\n", ct)
    print("\n% within each level:\n", (ct.div(ct.sum(axis=1),axis=0)*100).round(1))

    positive = ct.loc[['Agree','Strongly Agree']].sum()
    print("\nSum of Agree + Strongly Agree by Group:\n", positive)

    code_col = f"{col}_code"
    df[code_col] = df[col].map(likert_map)
    sub = df.dropna(subset=[code_col, 'Group'])
    
    
    # ==== Shapiro–Wilk per group ====
    print("\nShapiro–Wilk normality test per Group:")
    normal_pvals = []
    for g in sub['Group'].unique():
        vals = sub.loc[sub['Group']==g, code_col]
        w_stat, p_norm = shapiro(vals)
        normal_pvals.append(p_norm)
        print(f"  {g:<20} W={w_stat:.3f}, p={p_norm:.3f}")
    if all(p > 0.05 for p in normal_pvals):
        print("  → All groups look roughly normal (p > .05)")
    else:
        print("  → At least one group is non‑normal (p ≤ .05), using Kruskal–Wallis")
   
    
    # ==== Kruskal–Wallis ====
    groups = sub['Group'].unique()

    samples = [sub.loc[sub['Group']==g, code_col] for g in groups]
    h_stat, p_val = kruskal(*samples)
    print(f"\nKruskal–Wallis H = {h_stat:.2f}, p = {p_val:.3f}")
    
    # pairwise follow‑ups as before…
    if p_val < 0.1:
        m = len(groups)*(len(groups)-1)/2
        alpha_bonf = 0.05 / m
        print(f" Pairwise Mann–Whitney U tests (α′={alpha_bonf:.4f}):")
        for g1, g2 in itertools.combinations(groups, 2):
            a = sub.loc[sub['Group']==g1, code_col]
            b = sub.loc[sub['Group']==g2, code_col]
            u, p_u = mannwhitneyu(a, b, alternative='two-sided')
            p_adj = min(p_u * m, 1.0)
            sig = "yes" if p_adj < 0.05 else "no"
            print(f"  {g1} vs {g2}: U={u}, raw p={p_u:.3f}, adj p={p_adj:.3f} → sig? {sig}")
    print("-"*60)
# Out:
# === Efectiveness ===
#
# Counts:
#  Group              ExternalInformation  Framing  Salience  Simplification
# Efectiveness
# Agree                               14       16        12              14
# Disagree                             2        1         2               2
# Neutral                              3        4         8               6
# Strongly Agree                      11        7         6               8
# Strongly Disagree                    0        2         2               0
#
# % within each level:
#  Group              ExternalInformation  Framing  Salience  Simplification
# Efectiveness
# Agree                             25.0     28.6      21.4            25.0
# Disagree                          28.6     14.3      28.6            28.6
# Neutral                           14.3     19.0      38.1            28.6
# Strongly Agree                    34.4     21.9      18.8            25.0
# Strongly Disagree                  0.0     50.0      50.0             0.0
#
# Sum of Agree + Strongly Agree by Group:
#  Group
# ExternalInformation    25
# Framing                23
# Salience               18
# Simplification         22
# dtype: int64
#
# Shapiro–Wilk normality test per Group:
#   Salience             W=0.877, p=0.002
#   Framing              W=0.791, p=0.000
#   Simplification       W=0.854, p=0.001
#   ExternalInformation  W=0.804, p=0.000
#   → At least one group is non‑normal (p ≤ .05), using Kruskal–Wallis
#
# Kruskal–Wallis H = 4.42, p = 0.220
# ------------------------------------------------------------
#
# === Transparency ===
#
# Counts:
#  Group              ExternalInformation  Framing  Salience  Simplification
# Transparency
# Agree                               16       19        16              19
# Disagree                             2        0         2               1
# Neutral                              2        2         3               3
# Strongly Agree                      10        7         9               7
# Strongly Disagree                    0        2         0               0
#
# % within each level:
#  Group              ExternalInformation  Framing  Salience  Simplification
# Transparency
# Agree                             22.9     27.1      22.9            27.1
# Disagree                          40.0      0.0      40.0            20.0
# Neutral                           20.0     20.0      30.0            30.0
# Strongly Agree                    30.3     21.2      27.3            21.2
# Strongly Disagree                  0.0    100.0       0.0             0.0
#
# Sum of Agree + Strongly Agree by Group:
#  Group
# ExternalInformation    26
# Framing                26
# Salience               25
# Simplification         26
# dtype: int64
#
# Shapiro–Wilk normality test per Group:
#   Salience             W=0.804, p=0.000
#   Framing              W=0.685, p=0.000
#   Simplification       W=0.776, p=0.000
#   ExternalInformation  W=0.779, p=0.000
#   → At least one group is non‑normal (p ≤ .05), using Kruskal–Wallis
#
# Kruskal–Wallis H = 0.57, p = 0.904
# ------------------------------------------------------------
#
# === Persuadiveness ===
#
# Counts:
#  Group              ExternalInformation  Framing  Salience  Simplification
# Persuadiveness
# Agree                               13       14        13              16
# Disagree                             2        2         5               3
# Neutral                              3        5         5               7
# Strongly Agree                      12        7         6               4
# Strongly Disagree                    0        2         1               0
#
# % within each level:
#  Group              ExternalInformation  Framing  Salience  Simplification
# Persuadiveness
# Agree                             23.2     25.0      23.2            28.6
# Disagree                          16.7     16.7      41.7            25.0
# Neutral                           15.0     25.0      25.0            35.0
# Strongly Agree                    41.4     24.1      20.7            13.8
# Strongly Disagree                  0.0     66.7      33.3             0.0
#
# Sum of Agree + Strongly Agree by Group:
#  Group
# ExternalInformation    25
# Framing                21
# Salience               19
# Simplification         20
# dtype: int64
#
# Shapiro–Wilk normality test per Group:
#   Salience             W=0.877, p=0.002
#   Framing              W=0.840, p=0.000
#   Simplification       W=0.847, p=0.001
#   ExternalInformation  W=0.799, p=0.000
#   → At least one group is non‑normal (p ≤ .05), using Kruskal–Wallis
#
# Kruskal–Wallis H = 6.38, p = 0.095
#  Pairwise Mann–Whitney U tests (α′=0.0083):
#   Salience vs Framing: U=415.5, raw p=0.595, adj p=1.000 → sig? no
#   Salience vs Simplification: U=442.0, raw p=0.905, adj p=1.000 → sig? no
#   Salience vs ExternalInformation: U=316.0, raw p=0.036, adj p=0.217 → sig? no
#   Framing vs Simplification: U=483.5, raw p=0.599, adj p=1.000 → sig? no
#   Framing vs ExternalInformation: U=348.5, raw p=0.110, adj p=0.662 → sig? no
#   Simplification vs ExternalInformation: U=307.5, raw p=0.024, adj p=0.143 → sig? no
# ------------------------------------------------------------
#
# === Scrutability ===
#
# Counts:
#  Group              ExternalInformation  Framing  Salience  Simplification
# Scrutability
# Agree                               16       17        10              18
# Disagree                             1        0         4               2
# Neutral                              5        6         3               3
# Strongly Agree                       8        6        11               7
# Strongly Disagree                    0        1         2               0
#
# % within each level:
#  Group              ExternalInformation  Framing  Salience  Simplification
# Scrutability
# Agree                             26.2     27.9      16.4            29.5
# Disagree                          14.3      0.0      57.1            28.6
# Neutral                           29.4     35.3      17.6            17.6
# Strongly Agree                    25.0     18.8      34.4            21.9
# Strongly Disagree                  0.0     33.3      66.7             0.0
#
# Sum of Agree + Strongly Agree by Group:
#  Group
# ExternalInformation    24
# Framing                23
# Salience               21
# Simplification         25
# dtype: int64
#
# Shapiro–Wilk normality test per Group:
#   Salience             W=0.828, p=0.000
#   Framing              W=0.792, p=0.000
#   Simplification       W=0.789, p=0.000
#   ExternalInformation  W=0.832, p=0.000
#   → At least one group is non‑normal (p ≤ .05), using Kruskal–Wallis
#
# Kruskal–Wallis H = 0.36, p = 0.949
# ------------------------------------------------------------
#
# === Efficiency ===
#
# Counts:
#  Group              ExternalInformation  Framing  Salience  Simplification
# Efficiency
# Agree                               15       11        10              12
# Disagree                             3        1         4               4
# Neutral                              3        7         5               6
# Strongly Agree                       9        8        10               8
# Strongly Disagree                    0        3         1               0
#
# % within each level:
#  Group              ExternalInformation  Framing  Salience  Simplification
# Efficiency
# Agree                             31.2     22.9      20.8            25.0
# Disagree                          25.0      8.3      33.3            33.3
# Neutral                           14.3     33.3      23.8            28.6
# Strongly Agree                    25.7     22.9      28.6            22.9
# Strongly Disagree                  0.0     75.0      25.0             0.0
#
# Sum of Agree + Strongly Agree by Group:
#  Group
# ExternalInformation    24
# Framing                19
# Salience               20
# Simplification         20
# dtype: int64
#
# Shapiro–Wilk normality test per Group:
#   Salience             W=0.860, p=0.001
#   Framing              W=0.849, p=0.001
#   Simplification       W=0.862, p=0.001
#   ExternalInformation  W=0.811, p=0.000
#   → At least one group is non‑normal (p ≤ .05), using Kruskal–Wallis
#
# Kruskal–Wallis H = 1.09, p = 0.781
# ------------------------------------------------------------
#
# === Trust ===
#
# Counts:
#  Group              ExternalInformation  Framing  Salience  Simplification
# Trust
# Agree                               17       13        13              17
# Disagree                             1        1         3               1
# Neutral                              5        8         9               7
# Strongly Agree                       7        7         4               5
# Strongly Disagree                    0        1         1               0
#
# % within each level:
#  Group              ExternalInformation  Framing  Salience  Simplification
# Trust
# Agree                             28.3     21.7      21.7            28.3
# Disagree                          16.7     16.7      50.0            16.7
# Neutral                           17.2     27.6      31.0            24.1
# Strongly Agree                    30.4     30.4      17.4            21.7
# Strongly Disagree                  0.0     50.0      50.0             0.0
#
# Sum of Agree + Strongly Agree by Group:
#  Group
# ExternalInformation    24
# Framing                20
# Salience               17
# Simplification         22
# dtype: int64
#
# Shapiro–Wilk normality test per Group:
#   Salience             W=0.889, p=0.005
#   Framing              W=0.863, p=0.001
#   Simplification       W=0.834, p=0.000
#   ExternalInformation  W=0.825, p=0.000
#   → At least one group is non‑normal (p ≤ .05), using Kruskal–Wallis
#
# Kruskal–Wallis H = 4.04, p = 0.257
# ------------------------------------------------------------
#
# === Satisfaction ===
#
# Counts:
#  Group              ExternalInformation  Framing  Salience  Simplification
# Satisfaction
# Agree                               14       14        14              18
# Disagree                             0        0         2               1
# Neutral                              4        7         7               8
# Strongly Agree                      12        8         5               3
# Strongly Disagree                    0        1         2               0
#
# % within each level:
#  Group              ExternalInformation  Framing  Salience  Simplification
# Satisfaction
# Agree                             23.3     23.3      23.3            30.0
# Disagree                           0.0      0.0      66.7            33.3
# Neutral                           15.4     26.9      26.9            30.8
# Strongly Agree                    42.9     28.6      17.9            10.7
# Strongly Disagree                  0.0     33.3      66.7             0.0
#
# Sum of Agree + Strongly Agree by Group:
#  Group
# ExternalInformation    26
# Framing                22
# Salience               19
# Simplification         21
# dtype: int64
#
# Shapiro–Wilk normality test per Group:
#   Salience             W=0.858, p=0.001
#   Framing              W=0.826, p=0.000
#   Simplification       W=0.811, p=0.000
#   ExternalInformation  W=0.787, p=0.000
#   → At least one group is non‑normal (p ≤ .05), using Kruskal–Wallis
#
# Kruskal–Wallis H = 9.23, p = 0.026
#  Pairwise Mann–Whitney U tests (α′=0.0083):
#   Salience vs Framing: U=374.5, raw p=0.236, adj p=1.000 → sig? no
#   Salience vs Simplification: U=430.5, raw p=0.758, adj p=1.000 → sig? no
#   Salience vs ExternalInformation: U=288.0, raw p=0.010, adj p=0.063 → sig? no
#   Framing vs Simplification: U=515.0, raw p=0.294, adj p=1.000 → sig? no
#   Framing vs ExternalInformation: U=360.0, raw p=0.153, adj p=0.915 → sig? no
#   Simplification vs ExternalInformation: U=286.0, raw p=0.008, adj p=0.047 → sig? yes
# ------------------------------------------------------------

# %%
num_map = {
  'Strongly Disagree': 1,
  'Disagree':          2,
  'Neutral':           3,
  'Agree':             4,
  'Strongly Agree':    5
}
df['SatisfactionScore'] = df['Satisfaction'].map(num_map)

# Compute group means
df.groupby('Group')['SatisfactionScore'].mean()

means = df.groupby('Group')['SatisfactionScore'].mean()
print(means.loc[['ExternalInformation','Simplification']])
# Out:
# Group
# ExternalInformation    4.266667
# Simplification         3.766667
# Name: SatisfactionScore, dtype: float64
